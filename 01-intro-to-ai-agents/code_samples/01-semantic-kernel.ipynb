# %% [markdown]
# # Semantic Kernel
#
# In this code sample, you will use the [Semantic Kernel](https://aka.ms/ai-agents-beginners/semantic-kernel) AI Framework to create a basic agent.
#
# The goal of this sample is to show you the steps that we will later use in the additional code samples when implementing the different agentic patterns.

# %% [markdown]
# ## Import the Needed Python Packages

# %%
# !pip install semantic_kernel
# !pip install dotenv
# Out:
# Collecting semantic_kernel
#   Downloading semantic_kernel-1.34.0-py3-none-any.whl.metadata (12 kB)
# Collecting azure-ai-projects>=1.0.0b11 (from semantic_kernel)
#   Downloading azure_ai_projects-1.0.0b12-py3-none-any.whl.metadata (22 kB)
# Collecting azure-ai-agents>=1.1.0b1 (from semantic_kernel)
#   Downloading azure_ai_agents-1.1.0b4-py3-none-any.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp~=3.8 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (3.11.15)
# Collecting cloudevents~=1.0 (from semantic_kernel)
#   Downloading cloudevents-1.12.0-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (2.11.7)
# Collecting pydantic-settings~=2.0 (from semantic_kernel)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: defusedxml~=0.7 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (0.7.1)
# Collecting azure-identity>=1.13 (from semantic_kernel)
#   Downloading azure_identity-1.23.0-py3-none-any.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.9/81.9 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (2.0.2)
# Requirement already satisfied: openai>=1.67 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (1.94.0)
# Collecting openapi_core<0.20,>=0.18 (from semantic_kernel)
#   Downloading openapi_core-0.19.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: websockets<16,>=13 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (15.0.1)
# Collecting aiortc>=1.9.0 (from semantic_kernel)
#   Downloading aiortc-1.13.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting opentelemetry-api~=1.24 (from semantic_kernel)
#   Downloading opentelemetry_api-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk~=1.24 (from semantic_kernel)
#   Downloading opentelemetry_sdk-1.35.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting prance<25.4.9,>=23.6.21 (from semantic_kernel)
#   Downloading prance-25.4.8.0-py3-none-any.whl.metadata (13 kB)
# Collecting pybars4~=0.9 (from semantic_kernel)
#   Downloading pybars4-0.9.13.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: jinja2~=3.1 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (3.1.6)
# Requirement already satisfied: nest-asyncio~=1.6 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (1.6.0)
# Requirement already satisfied: scipy>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (1.15.3)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (5.29.5)
# Requirement already satisfied: typing-extensions>=4.13 in /usr/local/lib/python3.11/dist-packages (from semantic_kernel) (4.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp~=3.8->semantic_kernel) (1.20.1)
# Collecting aioice<1.0.0,>=0.10.1 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading aioice-0.10.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting av<15.0.0,>=14.0.0 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.6 kB)
# Requirement already satisfied: cffi>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from aiortc>=1.9.0->semantic_kernel) (1.17.1)
# Collecting cryptography>=44.0.0 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading cryptography-45.0.5-cp311-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Requirement already satisfied: google-crc32c>=1.1 in /usr/local/lib/python3.11/dist-packages (from aiortc>=1.9.0->semantic_kernel) (1.7.1)
# Collecting pyee>=13.0.0 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading pyee-13.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting pylibsrtp>=0.10.0 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting pyopenssl>=25.0.0 (from aiortc>=1.9.0->semantic_kernel)
#   Downloading pyopenssl-25.1.0-py3-none-any.whl.metadata (17 kB)
# Collecting isodate>=0.6.1 (from azure-ai-agents>=1.1.0b1->semantic_kernel)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-agents>=1.1.0b1->semantic_kernel)
#   Downloading azure_core-1.35.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 2.9 MB/s eta 0:00:00
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects>=1.0.0b11->semantic_kernel)
#   Downloading azure_storage_blob-12.25.1-py3-none-any.whl.metadata (26 kB)
# Collecting msal>=1.30.0 (from azure-identity>=1.13->semantic_kernel)
#   Downloading msal-1.32.3-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity>=1.13->semantic_kernel)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting deprecation<3.0,>=2.0 (from cloudevents~=1.0->semantic_kernel)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2~=3.1->semantic_kernel) (3.0.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai>=1.67->semantic_kernel) (4.67.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.18.0 in /usr/local/lib/python3.11/dist-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (4.24.0)
# Collecting jsonschema-path<0.4.0,>=0.3.1 (from openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading jsonschema_path-0.3.4-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from openapi_core<0.20,>=0.18->semantic_kernel) (10.7.0)
# Collecting openapi-schema-validator<0.7.0,>=0.6.0 (from openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading openapi_schema_validator-0.6.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting openapi-spec-validator<0.8.0,>=0.7.1 (from openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading openapi_spec_validator-0.7.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting parse (from openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading parse-1.20.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting werkzeug<3.1.2 (from openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading werkzeug-3.1.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api~=1.24->semantic_kernel) (8.7.0)
# Collecting opentelemetry-semantic-conventions==0.56b0 (from opentelemetry-sdk~=1.24->semantic_kernel)
#   Downloading opentelemetry_semantic_conventions-0.56b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: chardet>=5.2 in /usr/local/lib/python3.11/dist-packages (from prance<25.4.9,>=23.6.21->semantic_kernel) (5.2.0)
# Collecting ruamel.yaml>=0.18.10 (from prance<25.4.9,>=23.6.21->semantic_kernel)
#   Downloading ruamel.yaml-0.18.14-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from prance<25.4.9,>=23.6.21->semantic_kernel) (2.32.3)
# Requirement already satisfied: packaging>=24.2 in /usr/local/lib/python3.11/dist-packages (from prance<25.4.9,>=23.6.21->semantic_kernel) (24.2)
# Collecting PyMeta3>=0.5.1 (from pybars4~=0.9->semantic_kernel)
#   Downloading PyMeta3-0.5.1.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic_kernel) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic_kernel) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=2.10.0,!=2.10.1,!=2.10.2,!=2.10.3,<2.12,>=2.0->semantic_kernel) (0.4.1)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings~=2.0->semantic_kernel)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Collecting dnspython>=2.0.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic_kernel)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting ifaddr>=0.2.0 (from aioice<1.0.0,>=0.10.1->aiortc>=1.9.0->semantic_kernel)
#   Downloading ifaddr-0.2.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.67->semantic_kernel) (3.10)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core>=1.30.0->azure-ai-agents>=1.1.0b1->semantic_kernel) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0.0->aiortc>=1.9.0->semantic_kernel) (2.22)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic_kernel) (2025.7.9)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai>=1.67->semantic_kernel) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.67->semantic_kernel) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api~=1.24->semantic_kernel) (3.23.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.18.0->openapi_core<0.20,>=0.18->semantic_kernel) (0.26.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel) (6.0.2)
# Collecting pathable<0.5.0,>=0.4.1 (from jsonschema-path<0.4.0,>=0.3.1->openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading pathable-0.4.4-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity>=1.13->semantic_kernel) (2.10.1)
# Collecting rfc3339-validator (from openapi-schema-validator<0.7.0,>=0.6.0->openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting lazy-object-proxy<2.0.0,>=1.7.1 (from openapi-spec-validator<0.8.0,>=0.7.1->openapi_core<0.20,>=0.18->semantic_kernel)
#   Downloading lazy_object_proxy-1.11.0-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic_kernel) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.3->prance<25.4.9,>=23.6.21->semantic_kernel) (2.4.0)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.18.10->prance<25.4.9,>=23.6.21->semantic_kernel)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Downloading semantic_kernel-1.34.0-py3-none-any.whl (873 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.2/873.2 kB 22.3 MB/s eta 0:00:00
# Downloading aiortc-1.13.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.9/92.9 kB 7.3 MB/s eta 0:00:00
# Downloading azure_ai_agents-1.1.0b4-py3-none-any.whl (200 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.4/200.4 kB 13.7 MB/s eta 0:00:00
# Downloading azure_ai_projects-1.0.0b12-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 10.5 MB/s eta 0:00:00
# Downloading azure_identity-1.23.0-py3-none-any.whl (186 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 186.1/186.1 kB 10.8 MB/s eta 0:00:00
# Downloading cloudevents-1.12.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 3.6 MB/s eta 0:00:00
# Downloading openapi_core-0.19.5-py3-none-any.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 7.1 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.35.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.6/65.6 kB 5.0 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.35.0-py3-none-any.whl (119 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 7.8 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.56b0-py3-none-any.whl (201 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.6/201.6 kB 13.7 MB/s eta 0:00:00
# Downloading prance-25.4.8.0-py3-none-any.whl (36 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 2.7 MB/s eta 0:00:00
# Downloading aioice-0.10.1-py3-none-any.whl (24 kB)
# Downloading av-14.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 48.4 MB/s eta 0:00:00
# Downloading azure_core-1.35.0-py3-none-any.whl (210 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 16.5 MB/s eta 0:00:00
# Downloading azure_storage_blob-12.25.1-py3-none-any.whl (406 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 407.0/407.0 kB 24.5 MB/s eta 0:00:00
# Downloading cryptography-45.0.5-cp311-abi3-manylinux_2_34_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 96.2 MB/s eta 0:00:00
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jsonschema_path-0.3.4-py3-none-any.whl (14 kB)
# Downloading msal-1.32.3-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.4/115.4 kB 8.5 MB/s eta 0:00:00
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading openapi_schema_validator-0.6.3-py3-none-any.whl (8.8 kB)
# Downloading openapi_spec_validator-0.7.2-py3-none-any.whl (39 kB)
# Downloading pyee-13.0.0-py3-none-any.whl (15 kB)
# Downloading pylibsrtp-0.12.0-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.8 MB/s eta 0:00:00
# Downloading pyopenssl-25.1.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading ruamel.yaml-0.18.14-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.6/118.6 kB 9.3 MB/s eta 0:00:00
# Downloading werkzeug-3.1.1-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.4/224.4 kB 17.0 MB/s eta 0:00:00
# Downloading parse-1.20.2-py2.py3-none-any.whl (20 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 21.1 MB/s eta 0:00:00
# Downloading ifaddr-0.2.0-py3-none-any.whl (12 kB)
# Downloading lazy_object_proxy-1.11.0-py3-none-any.whl (16 kB)
# Downloading pathable-0.4.4-py3-none-any.whl (9.6 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 40.1 MB/s eta 0:00:00
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Building wheels for collected packages: pybars4, PyMeta3
#   Building wheel for pybars4 (setup.py) ... done
#   Created wheel for pybars4: filename=pybars4-0.9.13-py3-none-any.whl size=14340 sha256=255d4883cc13f8b47a24dd459e1476c27a66843f01613d37a4c59448db08b56d
#   Stored in directory: /root/.cache/pip/wheels/9d/91/9b/2590c830475e613f1996fe9ce7876d5d31c346fb73a48838ad
#   Building wheel for PyMeta3 (setup.py) ... done
#   Created wheel for PyMeta3: filename=PyMeta3-0.5.1-py3-none-any.whl size=16449 sha256=ebc35500afb85977aa6b01926b9c2241154d7a363bf44269c8066caeaf9655a2
#   Stored in directory: /root/.cache/pip/wheels/67/18/5a/5a3a19ff18c8118a8dd11204dcde08349c2bbbdd77ac45b6a7
# Successfully built pybars4 PyMeta3
# Installing collected packages: PyMeta3, parse, ifaddr, werkzeug, ruamel.yaml.clib, rfc3339-validator, python-dotenv, pyee, pybars4, pathable, lazy-object-proxy, isodate, dnspython, deprecation, av, ruamel.yaml, pylibsrtp, opentelemetry-api, jsonschema-path, cryptography, cloudevents, azure-core, aioice, pyopenssl, pydantic-settings, prance, opentelemetry-semantic-conventions, azure-storage-blob, azure-ai-agents, opentelemetry-sdk, openapi-schema-validator, msal, azure-ai-projects, aiortc, openapi-spec-validator, msal-extensions, openapi_core, azure-identity, semantic_kernel
#   Attempting uninstall: werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 45.0.5 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.1.0 which is incompatible.
# Successfully installed PyMeta3-0.5.1 aioice-0.10.1 aiortc-1.13.0 av-14.4.0 azure-ai-agents-1.1.0b4 azure-ai-projects-1.0.0b12 azure-core-1.35.0 azure-identity-1.23.0 azure-storage-blob-12.25.1 cloudevents-1.12.0 cryptography-45.0.5 deprecation-2.1.0 dnspython-2.7.0 ifaddr-0.2.0 isodate-0.7.2 jsonschema-path-0.3.4 lazy-object-proxy-1.11.0 msal-1.32.3 msal-extensions-1.3.1 openapi-schema-validator-0.6.3 openapi-spec-validator-0.7.2 openapi_core-0.19.5 opentelemetry-api-1.35.0 opentelemetry-sdk-1.35.0 opentelemetry-semantic-conventions-0.56b0 parse-1.20.2 pathable-0.4.4 prance-25.4.8.0 pybars4-0.9.13 pydantic-settings-2.10.1 pyee-13.0.0 pylibsrtp-0.12.0 pyopenssl-25.1.0 python-dotenv-1.1.1 rfc3339-validator-0.1.4 ruamel.yaml-0.18.14 ruamel.yaml.clib-0.2.12 semantic_kernel-1.34.0 werkzeug-3.1.1
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from dotenv) (1.1.1)
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Installing collected packages: dotenv
# Successfully installed dotenv-0.9.9

# %%
import os
from typing import Annotated
from openai import AsyncOpenAI

from dotenv import load_dotenv

from semantic_kernel.agents import ChatCompletionAgent, ChatHistoryAgentThread
from semantic_kernel.connectors.ai.open_ai import OpenAIChatCompletion
from semantic_kernel.functions import kernel_function

# %% [markdown]
# ## Creating the Client
#
# In this sample, we will use [GitHub Models](https://aka.ms/ai-agents-beginners/github-models) for access to the LLM.
#
# The `ai_model_id` is defined as `gpt-4o-mini`. Try changing the model to another model available on the GitHub Models marketplace to see the different results.
#
# For us to use the `Azure Inference SDK` that is used for the `base_url` for GitHub Models, we will use the `OpenAIChatCompletion` connector within Semantic Kernel. There are also other [available connectors](https://learn.microsoft.com/semantic-kernel/concepts/ai-services/chat-completion) to use Semantic Kernel for other model providers.

# %%
import random

# Define a sample plugin for the sample

class DestinationsPlugin:
    """A List of Random Destinations for a vacation."""

    def __init__(self):
        # List of vacation destinations
        self.destinations = [
            "Barcelona, Spain",
            "Paris, France",
            "Berlin, Germany",
            "Tokyo, Japan",
            "Sydney, Australia",
            "New York, USA",
            "Cairo, Egypt",
            "Cape Town, South Africa",
            "Rio de Janeiro, Brazil",
            "Bali, Indonesia"
        ]
        # Track last destination to avoid repeats
        self.last_destination = None

    @kernel_function(description="Provides a random vacation destination.")
    def get_random_destination(self) -> Annotated[str, "Returns a random vacation destination."]:
        # Get available destinations (excluding last one if possible)
        available_destinations = self.destinations.copy()
        if self.last_destination and len(available_destinations) > 1:
            available_destinations.remove(self.last_destination)

        # Select a random destination
        destination = random.choice(available_destinations)

        # Update the last destination
        self.last_destination = destination

        return destination

# %%
from google.colab import userdata  # GITHUB_TOKEN declared in colab secret

# %%
load_dotenv()
client = AsyncOpenAI(
    api_key= userdata.get('GITHUB_TOKEN'), #os.environ.get("GITHUB_TOKEN")
    base_url="https://models.inference.ai.azure.com/",
)

# Create an AI Service that will be used by the `ChatCompletionAgent`
chat_completion_service = OpenAIChatCompletion(
    ai_model_id="gpt-4o-mini",
    async_client=client,
)

# %% [markdown]
# ## Creating the Agent
#
# Below we create the Agent called `TravelAgent`.
#
# For this example, we are using very simple instructions. You can change these instructions to see how the agent responds differently.

# %%
agent = ChatCompletionAgent(
    service=chat_completion_service,
    plugins=[DestinationsPlugin()],
    name="TravelAgent",
    instructions="You are a helpful AI Agent that can help plan vacations for customers at random destinations",
)

# %% [markdown]
# ## Running the Agent
#
# Now we can run the Agent by defining a thread of type `ChatHistoryAgentThread`.  Any required system messages are provided to the agent's invoke_stream `messages` keyword argument.
#
# After these are defined, we create a `user_inputs` that will be what the user is sending to the agent. In this case, we have set this message to `Plan me a sunny vacation`.
#
# Feel free to change this message to see how the agent responds differently.

# %%
async def main():
    # Create a new thread for the agent
    # If no thread is provided, a new thread will be
    # created and returned with the initial response
    thread: ChatHistoryAgentThread | None = None

    user_inputs = [
        "Plan me a day trip.",
        "I want another destination",
    ]

    for user_input in user_inputs:
        print(f"# User: {user_input}\n")
        first_chunk = True
        async for response in agent.invoke_stream(
            messages=user_input, thread=thread,
        ):
            # 5. Print the response
            if first_chunk:
                print(f"# {response.name}: ", end="", flush=True)
                first_chunk = False
            print(f"{response}", end="", flush=True)
            thread = response.thread
        print()
        print("\n-----------\n\n")

    # Clean up the thread
    await thread.delete() if thread else None

await main()
# Out:
# # User: Plan me a day trip.
#
# # TravelAgent: I've planned a day trip for you to Sydney, Australia! Here's a suggested itinerary to make the most of your day:
#
# ### Morning:
# - **Breakfast at a Local Café:** Start your day at a cozy café in The Rocks, known for its historic buildings and great breakfast options.
# - **Sydney Opera House:** Visit the iconic Sydney Opera House. Take a guided tour to learn about its architecture and history.
#
# ### Midday:
# - **Lunch at Circular Quay:** Enjoy lunch with a view at one of the restaurants in Circular Quay. You can try some local seafood or Australian cuisine.
# - **Sydney Harbour Bridge Climb:** Experience the breathtaking views of the harbor by climbing the Sydney Harbour Bridge. It's an unforgettable adventure!
#
# ### Afternoon:
# - **Royal Botanic Garden:** Take a leisurely stroll through the beautiful Royal Botanic Garden. It’s a great spot to relax and enjoy nature.
# - **Art Gallery of New South Wales:** Visit the art gallery to explore Australian and international art collections. Admission is free for the main galleries.
#
# ### Evening:
# - **Sunset at Bondi Beach:** Head to Bondi Beach to watch the sunset. Enjoy the beach atmosphere, take a walk along the shore, or relax on the sand.
# - **Dinner at Bondi:** Dine at one of the beachside restaurants or cafes, enjoying fresh seafood or international cuisine.
#
# ### Optional Night Activity:
# - **Nightlife in Darling Harbour:** If you have energy left, explore the vibrant nightlife at Darling Harbour, with plenty of bars and entertainment options.
#
# Enjoy your day trip to Sydney!
#
# -----------
#
#
# # User: I want another destination
#
# # TravelAgent: I've planned a day trip for you to Tokyo, Japan! Here's a suggested itinerary to explore this vibrant city:
#
# ### Morning:
# - **Breakfast at Tsukiji Outer Market:** Start your day with a traditional Japanese breakfast at the Tsukiji Outer Market. Try fresh sushi and other local delicacies.
# - **Senso-ji Temple:** Visit the historic Senso-ji Temple in Asakusa, Tokyo's oldest temple. Enjoy the vibrant Nakamise shopping street leading up to the temple.
#
# ### Midday:
# - **Lunch in Akihabara:** Head to Akihabara, known for its electronics and otaku culture. Grab lunch at a themed café or enjoy some ramen at one of the popular eateries.
# - **Akihabara Exploration:** Spend some time exploring the unique shops, arcades, and pop culture stores in the area.
#
# ### Afternoon:
# - **Shibuya Crossing:** Head to Shibuya to experience the famous Shibuya Crossing. Don’t forget to snap a photo with the Hachiko statue!
# - **Shopping in Harajuku:** Stroll down Takeshita Street in Harajuku, famous for its trendy shops and quirky fashion. This is a great spot for souvenir shopping.
